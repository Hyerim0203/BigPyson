# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
from scipy import stats
import math

# %%
train = pd.read_excel('./train_0922.xlsx')

# %%
train.drop('Unnamed: 0', inplace=True, axis=1)

# %%
test = pd.read_excel('./test.xlsx', header=1)

# %% [markdown]
# ## 타 방송사 편성표 관련 EDA

# %%
cj = pd.read_csv('./data/cj.csv')
lotte = pd.read_csv('./data/lotte.csv')
gs = pd.read_csv('./data/gs.csv')

# %%
def to_cat(df):
    Item = []

    for i in range(len(df)):
        item = df.iloc[i].상품명
        if '침대' in item:
            Item.append('a1')
        elif '소파' in item:
            Item.append('a2')
        elif '로젠카우치' in item:
            Item.append('a2')
        elif '테이블' in item:
            Item.append('a3')
        elif '스튤' in item:
            Item.append('a4')
        elif '의자' in item:
            Item.append('a4')
        elif '세탁기' in item:
            Item.append('b1')
        elif '냉장고' in item:
            Item.append('b2')
        elif '벽걸이에어컨' in item:
            Item.append('b3')
        elif '청소기' in item:
            Item.append('b4')
        elif '형' in item:
            Item.append('b5')
        elif '비데' in item:
            Item.append('e1')
        elif '샤워기' in item:
            Item.append('e2')
        elif '세제' in item:
            Item.append('e3')
        elif '원큘레이터' in item:
            Item.append('e4')
        elif '선풍기' in item:
            Item.append('e4')
        elif '선반' in item:
            Item.append('e5')
        elif '섬유유연제' in item:
            Item.append('e6')
        elif '안마매트' in item:
            Item.append('e7')
        elif '금고' in item:
            Item.append('e8')
        elif '안마기' in item:
            Item.append('e9')
        elif '창문형 에어컨' in item:
            Item.append('b3')
        elif '이동식에어컨' in item:
            Item.append('b3')
        elif '건조대' in item:
            Item.append('e10')
        elif '에어쿨러' in item:
            Item.append('e11')
        elif '냉풍기' in item:
            Item.append('e11')
        elif '베개' in item:
            Item.append('e12')
        elif '패치' in item:
            Item.append('e13')
        elif '건조대' in item:
            Item.append('e14')
        elif '패드' in item:
            Item.append('e15')
        elif '밸런스파워' in item:
            Item.append('e16')
        elif '거치대' in item:
            Item.append('e17')    
        elif '스타일러' in item:
            Item.append('h1')
        elif '선스틱' in item:
            Item.append('h2')
        elif '썬스틱' in item:
            Item.append('h2')    
        elif '샴푸' in item:
            Item.append('h3')
        elif '에센스' in item:
            Item.append('h4')
        elif '로션' in item:
            Item.append('h5')
        elif '샤워' in item:
            Item.append('h6')
        elif '바디로션' in item:
            Item.append('h6')    
        elif '헤어컬러' in item:
            Item.append('h7')
        elif '염색' in item:
            Item.append('h7')    
        elif '속눈썹' in item:
            Item.append('h8')
        elif '틴트' in item:
            Item.append('h9')
        elif '모공기기' in item:
            Item.append('h10')
        elif '네일' in item:
            Item.append('h11')
        elif '클렌져' in item:
            Item.append('h12')
        elif '지이링클' in item:
            Item.append('h13')
        elif '남성기초세트' in item:
            Item.append('h14')
        elif '마스크' in item:
            Item.append('h15')
        elif '다이어트' in item:
            Item.append('c1')
        elif '유산균' in item:
            Item.append('c2')
        elif '김치' in item:
            Item.append('d1')
        elif '돔' in item:
            Item.append('d2')
        elif '떡' in item:
            Item.append('d3')
        elif '냉면' in item:
            Item.append('d4')
        elif '오징어' in item:
            Item.append('d5')
        elif '닭발' in item:
            Item.append('d6')
        elif '국수' in item:
            Item.append('d7')
        elif '키위' in item:
            Item.append('d8')
        elif '쥐포' in item:
            Item.append('d9')
        elif '쥐치포' in item:
            Item.append('d9')    
        elif '우럭' in item:
            Item.append('d10')
        elif '만두' in item:
            Item.append('d11')
        elif '커피' in item:
            Item.append('d12')
        elif '가자미' in item:
            Item.append('d13')
        elif '전복' in item:
            Item.append('d14')
        elif '고등어' in item:
            Item.append('d15')
        elif '굴비' in item:
            Item.append('d16')
        elif '회' in item:
            Item.append('d17')
        elif '메로' in item:
            Item.append('d18')
        elif '고기' in item:
            Item.append('d19')
        elif '마시는한끼' in item:
            Item.append('d20')
        elif '두유' in item:
            Item.append('d21')
        elif '오리' in item:
            Item.append('d22')
        elif '옥수수' in item:
            Item.append('d23')
        elif '꽃게' in item:
            Item.append('d24')
        elif '감귤' in item:
            Item.append('d25')
        elif '쌀' in item:
            Item.append('d26')
        elif '갈치' in item:
            Item.append('d27')
        elif '삼계탕' in item:
            Item.append('d28')
        elif '장어' in item:
            Item.append('d29')
        elif '김' in item:
            Item.append('d30')
        elif '육포' in item:
            Item.append('d31')
        elif '더덕' in item:
            Item.append('d32')
        elif '대자리' in item:
            Item.append('k1')
        elif '침구' in item:
            Item.append('k2')
        elif '반팔셔츠' in item:
            Item.append("g1")
        elif '티셔츠' in item:
            Item.append("g2")
        elif '린넨' in item:
            Item.append("g3")
        elif '재킷' in item:
            Item.append("g4")
        elif '원피스' in item:
            Item.append("g5")
        elif '시스루' in item:
            Item.append("g6")
        elif '썸머셔츠' in item:
            Item.append("g7")
        elif '라인핏' in item:
            Item.append("g8")
        elif '팬츠' in item:
            Item.append("g9")
        elif '반바지' in item:
            Item.append("g10")
        elif '팬티' in item:
            Item.append("f1")
        elif '원피스' in item:
            Item.append("f2")
        elif '브라' in item:
            Item.append("f3")
        elif '란쥬' in item:
            Item.append("f4")
        elif '드로즈' in item:
            Item.append("f5")
        elif '언더셔츠' in item:
            Item.append("f6")
        elif '트렁크' in item:
            Item.append("f7")
        elif '런닝' in item:
            Item.append("f8")
        elif '언더탑' in item:
            Item.append("f9")
        elif '용기' in item:
            Item.append('j1')
        elif '프라이팬' in item:
            Item.append('j2')
        elif '후라이팬' in item:
            Item.append('j2')
        elif '밥솥' in item:
            Item.append('j3')
        elif '도마' in item:
            Item.append('j4')
        elif '칼' in item:
            Item.append('j5')
        elif '그릴' in item:
            Item.append('j6')
        elif '수세미' in item:
            Item.append('j7')
        elif '건조기' in item:
            Item.append('j8')
        elif '식기건조대' in item:
            Item.append('j9')
        elif '글라스' in item:
            Item.append('j10')
        elif '지퍼백' in item:
            Item.append('j11')
        elif '가스레인지' in item:
            Item.append('j12')
        elif '냄비' in item:
            Item.append('j13')
        elif '믹서기' in item:
            Item.append('j14')
        elif '에어프라이어' in item:
            Item.append('j15')
        elif '블렌더' in item:
            Item.append('j16')
        elif '텀블러' in item:
            Item.append('j17')
        elif '젤' in item:
            Item.append('j18')
        elif '블럭' in item:
            Item.append('j19')
        elif '가방' in item:
            Item.append('i1')
        elif '백' in item:
            Item.append('i1')    
        elif '모자' in item:
            Item.append('i2')   
        elif '선글라스' in item:
            Item.append('i3')   
        elif '화' in item:
            Item.append('i4')   
        elif '로퍼' in item:
            Item.append('i4')   
        elif '샌들' in item:
            Item.append('i4')   
        elif '슬립온' in item:
            Item.append('i4')   
        elif '지갑' in item:
            Item.append('i5')   
        elif '스카프' in item:
            Item.append('i6')   
        elif '양산' in item:
            Item.append('i7')   
        elif '모자' in item:
            Item.append('i8')   
        elif '카메라' in item:
            Item.append('i9')   
        elif '귀걸이' in item:
            Item.append('i10')   
        elif '목걸이' in item:
            Item.append('i10')   
        elif '주얼리' in item:
            Item.append('i10')   
        elif '팔찌' in item:
            Item.append('i10') 
        elif '용기' in item:
            Item.append('i11')   
        elif '프라이팬' in item:
            Item.append('i12')   
        elif '후라이팬' in item:
            Item.append('i12')  
        elif '밥솥' in item:
            Item.append('i13')
        elif '도마' in item:
            Item.append('i14')
        elif '칼' in item:
            Item.append('i15')
        elif '그릴' in item:
            Item.append('i16')
        elif '수세미' in item:
            Item.append('i17')
        elif '건조기' in item:
            Item.append('i18')
        elif '식기건조대' in item:
            Item.append('i18')
        elif '글라스' in item:
            Item.append('i19')
        elif '지퍼백' in item:
            Item.append('i20')
        elif '가스레인지' in item:
            Item.append('i21')
        elif '냄비' in item:
            Item.append('i22')
        elif '믹서기' in item:
            Item.append('i23')
        elif '에어프라이어' in item:
            Item.append('i24')    
        elif '블렌더' in item:
            Item.append('i25') 
        elif '텀블러' in item:
            Item.append('i26')
        elif '젤' in item:
            Item.append('i27') 
        elif '블럭' in item:
            Item.append('i28')     
        else:
            Item.append('etc')
        
    return Item

# %%
def column(df):
    df['방송일시'] = df['날짜'] + ' ' + df['시작시간']
    df['방송일시'] = df['방송일시'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d %H:%M'))
    df['시'] = df['방송일시'].map(lambda x: x.to_pydatetime().hour)

# %%
cj_item = to_cat(cj)
lotte_item = to_cat(lotte)
gs_item = to_cat(gs)

# %%
cj['분류'] = cj_item
lotte['분류'] = lotte_item
gs['분류'] = gs_item

# %%
column(cj)
column(lotte)
column(gs)

# %%
def to_largecat(df):
    
    cat = df['분류']
    largecat = []
    
    for x in cat:
        if 'a' in x: largecat.append('furniture')
        elif 'b' in x: largecat.append('elec')
        elif 'c' in x: largecat.append('health')
        elif 'd' in x: largecat.append('food')
        elif 'e' in x: largecat.append('life') # 생활용품
        elif 'f' in x: largecat.append('inner')
        elif 'g' in x: largecat.append('cloth')
        elif 'h' in x: largecat.append('beauty')
        elif 'i' in x: largecat.append('etc')
        elif 'j' in x: largecat.append('living') # 주방
        elif 'k' in x: largecat.append('bedding')
        else: largecat.append('etc')
    
    df['상품군'] = largecat

# %%
to_largecat(cj)
to_largecat(gs)
to_largecat(lotte)

# %%
def plot_hour_cat(df):
    hour_grouped = df.groupby(['시','상품군']).count()['상품명'].reset_index()
    plt.figure(figsize=(10,10))
    sns.barplot(data=hour_grouped, x='시', y='상품명', hue='상품군', dodge=False)

# %% [markdown]
# - ns shop

# %%
hour_grouped = train.groupby(['시','상품군'])
HourGroup = hour_grouped['new주문량'].sum()
HourGroup = HourGroup.reset_index()
plt.figure(figsize=(10,20))
sns.barplot(data=HourGroup, x='시', y='new주문량', hue='상품군', dodge=False)
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 49884 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 타방송사

# %%
plot_hour_cat(cj)
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 49884 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plot_hour_cat(gs)
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 49884 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plot_hour_cat(lotte)
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 49884 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
category = cj['상품군'].unique()

# %% [markdown]
# - ns shop

# %%
for cat in category:
    cat_grouped = train.groupby(['상품군','시'])['new주문량'].sum().reset_index()
    plt.figure(figsize=(10,5))
    plt.title(cat)
    sns.barplot(data=cat_grouped[cat_grouped['상품군']==cat], x='시', y='new주문량')
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 49884 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 타방송사

# %%
def plot_cat_hour(df):
    cat_grouped = df.groupby(['상품군','시']).count()['상품명'].reset_index()
    
    for cat in category:
        plt.figure(figsize=(10,5))
        plt.title(cat)
        d = cat_grouped[cat_grouped['상품군']==cat]
        sns.barplot(data=d, x='시', y='상품명')

# %%
plot_cat_hour(cj)
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 49884 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plot_cat_hour(lotte)
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 49884 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plot_cat_hour(gs)
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 49884 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\KSE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## FE(최종 데이터에 포함됨)

# %% [markdown]
# - 판매단가 log 변환

# %%
train['new판매단가'] = np.log(train['판매단가'])
train.drop('판매단가', inplace=True, axis=1)

# %% [markdown]
# - 주문량 log 변환

# %%
train['new주문량'] = np.log(train['주문량'])
train.drop('주문량', inplace=True, axis=1)

# %% [markdown]
# - 시간대

# %%
time = train.groupby('HOUR').aggregate(np.mean)

time_rank = {}
rank = 1 
for idx, row in time.sort_values(by='new주문량').iterrows():
    time_rank[idx] = rank
    rank += 1

# %%
prime_time = []

for idx, row in train.iterrows():
    prime_time.append(time_rank[row.HOUR])
    
train['prime_time'] = prime_time

# %% [markdown]
# - 요일

# %%
day = train.groupby('요일').aggregate(np.mean)

day_rank = {}
rank = 1 
for idx, row in day.sort_values(by='new주문량').iterrows():
    day_rank[idx] = rank
    rank += 1
    
prime_day = []

for idx, row in train.iterrows():
    prime_day.append(day_rank[row.요일])
    
train['prime_day'] = prime_day

# %% [markdown]
# - test랑 겹치는 마더코드 기준 : 노출시간 대비보다 좋음

# %%
intercode = set(test['마더코드'].unique()).intersection(set(train['마더코드'].unique()))
interitem = train[train['마더코드'].isin(intercode)]

# %%
code = interitem.groupby('마더코드').aggregate(np.mean)

code_rank = {}
rank = 1
for idx, row in code.sort_values(by='new주문량').iterrows():
    code_rank[idx] = rank
    rank += 1

top_code = []

for idx, row in train.iterrows():
    if row.마더코드 in code_rank.keys():
        top_code.append(code_rank[row.마더코드])
    else:
        top_code.append(0)
        
train['top_code'] = top_code

# %% [markdown]
# - 분류 기준 topcode

# %%
cat = train.groupby('분류').aggregate(np.mean)

cat_rank = {}
rank = 1
for idx, row in cat.sort_values(by='new주문량').iterrows():
    cat_rank[idx] = rank
    rank += 1

top_cat = []

for idx, row in train.iterrows():
    top_cat.append(cat_rank[row.분류])
    
train['top_cat'] = top_cat

# %% [markdown]
# - 분류 변수 원핫/pca

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA

# %%
enc1 = OneHotEncoder()
category = np.array(train['분류'])
category = category.reshape(-1, 1)

# %%
enc1.fit(category)
category_ = enc1.transform(category).toarray()

# %%
pca = PCA(n_components=2)
res = pca.fit_transform(category_)
res = pd.DataFrame(res, columns=['x1_cat','x2_cat'])

# %%
train['x1_cat'] = res['x1_cat']
train['x2_cat'] = res['x2_cat']

# %% [markdown]
# - 실제 날씨(서울)

# %%
real = train.groupby('실제_서울_날씨').aggregate(np.mean)

real_rank = {}
rank = 1
for idx, row in real.sort_values(by='new주문량').iterrows():
    real_rank[idx] = rank
    rank += 1

top_real_weather = []

for idx, row in train.iterrows():
    top_real_weather.append(real_rank[row.실제_서울_날씨])
    
train['top_real_weather'] = top_real_weather

# %% [markdown]
# - 실제 날씨 통합

# %%
real_total_weather = pd.read_excel('./data/날씨통합.xlsx')

# %%
train['실제_최고기온'] = real_total_weather['최고기온']
train['실제_최저기온'] = real_total_weather['최저기온']
train['실제_강수량'] = real_total_weather['강수량']
train['실제_평균풍속'] = real_total_weather['평균풍속']

# %% [markdown]
# - 빈도수 인코딩

# %%
# 빈도수인코딩(위의 원핫+pca와 비교해보기)
def add_frequency_encoding(data,column): 
    #데이터프레임,열을 받아서 빈도수인코딩열을 추가해줌
    enc_nom = (data.groupby(column).size())/len(data)
    data['freq_encode_{}'.format(column)] = data[column].apply(lambda x:enc_nom[x])
    print("freq_encode column was added")

# %%
add_frequency_encoding(train,'분류')
# Out:
# freq_encode column was added

# %% [markdown]
# ## split

# %%
#모든 카테고리에 대해 따로따로 자동 변수생성
category_list = train['상품군'].unique().tolist()
for i in category_list:
    #카테고리에 해당하는 주문량제외 train데이터 할당   -> 주문량 포함되어있음
    globals()['x_{}'.format(i)] = train.loc[train['상품군']==i] 
    #카테고리에 해당하는 train의 주문량을 할당
    globals()['y_{}'.format(i)] = train['new주문량'].loc[train['상품군']==i]

# %% [markdown]
# 1) 카테고리별로 x_train_카테고리 , x_test_카테고리, y_train_카테고리, y_test_카테고리

# %%
from sklearn.model_selection import train_test_split
for i in category_list:
    x_for_split = globals()['x_{}'.format(i)]
    y_for_split = globals()['y_{}'.format(i)]
    globals()['x_train_{}'.format(i)], globals()['x_test_{}'.format(i)], globals()['y_train_{}'.format(i)], globals()['y_test_{}'.format(i)] = train_test_split(x_for_split, y_for_split, test_size=0.33, random_state=1234)

# %% [markdown]
# 2) 카테고리별 20분 단위 3갈 각각 피팅

# %%
catlist = train['상품군'].unique()

# %%
#그룹내 방송행간의 시간차이(날짜-날짜) <= 해당그룹 최대 노출(분)인가? 
# 검토해서 분리하는 함수

def split_shoprow(df, time): 
    shoprow1 = pd.DataFrame()  # train
    shoprow2 = pd.DataFrame()  # validation 
    size = len(df)

    for i in range((size)-1):       
        if (df['방송일시'].iloc[i+1]-df['방송일시'].iloc[i] <= time):
            shoprow1 = shoprow1.append(df.iloc[i])
        else:
            shoprow2 = shoprow2.append(df.iloc[i])    
    i += 1
    shoprow2 = shoprow2.append(df.iloc[i])
            
    return shoprow1,shoprow2

# %% [markdown]
# - 실험

# %%
#기준시간. 방송끼리 이만큼 붙어있어야 같은 제품의 판매임.
criteria_time = pd.Timedelta('0 days 00:{}:00'.format(20))
# 3개를 기준으로, 방송타임 2개는 bigfold에 1개는smallfold에 넣겠다.
train_big_fold = pd.DataFrame()
train_small_fold = pd.DataFrame()
# 마더코드 100080에 실험
x1 = train[train['마더코드']==100080]
train_big_fold, train_small_fold = split_shoprow(x1,criteria_time) 
# 제대로 나옴
print(train_big_fold.head(15)['방송일시'])
print(train_small_fold.head(10)['방송일시'])
# Out:
# 175   2019-06-16 15:00:00
# 176   2019-06-16 15:20:00
# 306   2019-06-17 22:00:00
# 307   2019-06-17 22:20:00
# 339   2019-06-18 12:00:00
# 340   2019-06-18 12:20:00
# 466   2019-06-19 22:00:00
# 467   2019-06-19 22:20:00
# 567   2019-06-20 23:00:00
# 568   2019-06-20 23:20:00
# 730   2019-06-22 23:20:00
# 731   2019-06-22 23:40:00
# 761   2019-06-23 11:00:00
# 762   2019-06-23 11:20:00
# 915   2019-06-24 22:00:00
# Name: 방송일시, dtype: datetime64[ns]
# 177    2019-06-16 15:40:00
# 308    2019-06-17 22:40:00
# 341    2019-06-18 12:40:00
# 468    2019-06-19 22:40:00
# 569    2019-06-20 23:40:00
# 732    2019-06-23 00:00:00
# 763    2019-06-23 11:40:00
# 917    2019-06-24 22:40:00
# 950    2019-06-25 12:40:00
# 1143   2019-06-27 15:40:00
# Name: 방송일시, dtype: datetime64[ns]

# %% [markdown]
# - reindex(할필요없을듯)

# %%
for cat in catlist:
    globals()['x_{}'.format(cat)].index = np.arange(len(globals()['x_{}'.format(cat)]))

# %%
catlist
# Out:
# array(['inner', 'cloth', 'elec', 'living', 'food', 'health', 'bedding',
#        'furniture', 'beauty', 'etc', 'life'], dtype=object)

# %% [markdown]
# - 카테고리별로 split 하기

# %%
for cat in catlist:
    selec_cat = globals()['x_{}'.format(cat)]
    momcode_cat = selec_cat['마더코드'].unique()
    # 걍 한 카테고리에서 가장 노출시간이 긴 시간을 기준으로 해도 될듯?
    # 20분씩
    max_time = selec_cat['노출(분)'].max()
    criteria_time = pd.Timedelta('0 days 00:{}:00'.format(int(max_time)))
    T = pd.DataFrame()
    V = pd.DataFrame()
    
    for momcode in momcode_cat:
        mom = train[train['마더코드']==momcode]
        t, v = split_shoprow(mom, criteria_time) 
        T = T.append(t)
        V = V.append(v)
    
    globals()['{}_bigfold'.format(cat)] = T
    globals()['{}_smallfold'.format(cat)] = V

# %% [markdown]
# #### error

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# #### model 1) rf

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
rf.fit(beauty_bigfold, y_beauty)
predictions = rf.predict(shop_train_x_beauty)
mape = mean_absolute_percentage_error(y_train_beauty, predictions)
mape

# %% [markdown]
# #### model 2) dnn

# %% [markdown]
# - regularization

# %%
x_train_1.describe()
# Out:
#              노출(분)  holiday(includeSS)   실제_서울_최고기온   실제_서울_최저기온  \
# count  5033.000000         5033.000000  5033.000000  5033.000000
# mean     20.546592            0.317504    30.417803    22.363501
# std       3.596703            0.465552     2.969046     2.591747
# min       5.000000            0.000000    24.800000    16.100000
# 25%      20.000000            0.000000    28.200000    20.200000
# 50%      20.000000            0.000000    30.100000    22.300000
# 75%      20.000000            1.000000    32.500000    24.600000
# max      30.000000            1.000000    36.800000    27.900000
#
#        실제_서울_강수량(mm)   실제_수원_최고기온   실제_수원_최저기온  실제_수원_강수량(mm)   실제_파주_최고기온  \
# count    5033.000000  5033.000000  5033.000000    5033.000000  5033.000000
# mean        4.956408    30.430836    21.849235       3.882277    29.281860
# std        12.336896     2.790699     2.806643      13.206496     2.808008
# min         0.000000    25.200000    15.300000       0.000000    22.300000
# 25%         0.000000    28.000000    19.700000       0.000000    27.500000
# 50%         0.000000    30.200000    21.500000       0.000000    29.100000
# 75%         2.900000    32.200000    24.600000       1.000000    31.200000
# max        62.300000    36.500000    27.900000     108.000000    34.700000
#
#         실제_파주_최저기온  ...    예보_수원_강수량  예보_수원_일최고기온  예보_수원_일최저기온      new판매단가  \
# count  5033.000000  ...  5033.000000  5033.000000  5033.000000  5033.000000
# mean     19.972601  ...     2.902976    30.328116    22.036016    11.898127
# std       2.950269  ...     5.370899     2.209398     2.602339     1.309688
# min      13.500000  ...     0.000000    26.263158    16.000000     9.457200
# 25%      17.800000  ...     0.131579    28.631579    20.312500    10.913269
# 50%      19.900000  ...     1.250000    29.947368    21.500000    11.502875
# 75%      23.100000  ...     2.973684    31.789474    24.937500    12.992255
# max      24.700000  ...    30.789474    35.894737    26.000000    15.110238
#
#         prime_time    prime_day     top_code      top_cat       x1_cat  \
# count  5033.000000  5033.000000  5033.000000  5033.000000  5033.000000
# mean      9.241009     3.908007    10.049672    32.028412     0.002350
# std       5.875745     1.993451    17.080805    23.656923     0.250410
# min       1.000000     1.000000     0.000000     1.000000    -0.509676
# 25%       4.000000     2.000000     0.000000    11.000000    -0.011886
# 50%       9.000000     4.000000     0.000000    27.000000    -0.006265
# 75%      14.000000     6.000000    12.000000    50.000000    -0.004896
# max      20.000000     7.000000    64.000000    83.000000     0.837735
#
#             x2_cat
# count  5033.000000
# mean      0.001141
# std       0.246119
# min      -0.669941
# 25%       0.005879
# 50%       0.007684
# 75%       0.012942
# max       0.684854
#
# [8 rows x 31 columns]

# %%
reg_col = ['실제_서울_최고기온', '실제_서울_최저기온', '실제_서울_강수량(mm)', 
           '실제_수원_최고기온', '실제_수원_최저기온', '실제_수원_강수량(mm)',
           '실제_파주_최고기온', '실제_파주_최저기온', '실제_파주_강수량(mm)', 
           '예보_서울_강수확률', '예보_서울_강수량', '예보_서울_하늘상태', 
           '예보_서울_일최고기온', '예보_서울_일최저기온', '예보_일산_강수확률', 
           '예보_일산_강수량', '예보_일산_일최고기온', '예보_일산_일최저기온', 
           '예보_수원_강수확률', '예보_수원_강수량', '예보_수원_일최고기온',
           '예보_수원_일최저기온', 'new판매단가']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x_train_1[reg_col] = scaler.fit_transform((x_train_1[reg_col]))
x_val_1[reg_col] = scaler.fit_transform((x_val_1[reg_col]))
# Out:
# C:\Users\KSE\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\KSE\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\KSE\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\KSE\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
n_inputs = 31
n_h1 = 50
n_h2 = 50
n_outputs = 1

#### optimizer = sgd

m1 = Sequential()
m1.add(Dense(n_h1, input_dim=31, kernel_initializer='normal', activation='relu'))
m1.add(Dense(n_h2, input_dim=n_h1, kernel_initializer='normal', activation='relu'))
m1.add(Dense(n_outputs, input_dim=n_h2, kernel_initializer='normal'))

# %%
m1.compile(optimizer='adam', loss='mean_squared_error')

hist1=m1.fit(x_train_1, y_train, epochs=20, batch_size=20)
# Out:
# Epoch 1/20
# 252/252 [==============================] - 0s 2ms/step - loss: 0.8259
# Epoch 2/20
# 252/252 [==============================] - 0s 2ms/step - loss: 0.7816
# Epoch 3/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.7413
# Epoch 4/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.7179
# Epoch 5/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.6937
# Epoch 6/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.6754
# Epoch 7/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.6599
# Epoch 8/20
# 252/252 [==============================] - 0s 2ms/step - loss: 0.6683
# Epoch 9/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.6430
# Epoch 10/20
# 252/252 [==============================] - 1s 3ms/step - loss: 0.6387A: 0s - l
# Epoch 11/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.6380
# Epoch 12/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.6197
# Epoch 13/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.6234
# Epoch 14/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.6046
# Epoch 15/20
# 252/252 [==============================] - 0s 2ms/step - loss: 0.6006
# Epoch 16/20
# 252/252 [==============================] - 0s 2ms/step - loss: 0.6141
# Epoch 17/20
# 252/252 [==============================] - 1s 2ms/step - loss: 0.6074
# Epoch 18/20
# 252/252 [==============================] - 0s 2ms/step - loss: 0.5919
# Epoch 19/20
# 252/252 [==============================] - 0s 2ms/step - loss: 0.5942
# Epoch 20/20
# 252/252 [==============================] - 0s 2ms/step - loss: 0.5950

# %%
pred = m1.predict(x_train_1)

# %%
err = error(y_train, pred)
err
# Out:
# 70.2866615537398
